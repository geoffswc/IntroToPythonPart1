# %%
# Plotting and Programming in Python

# %%
# CH 5: Libraries

# %%
# Objectives:
#     1. explain what software libraries are and why programmers create and use them
#     2. write programs that import and use modules from python's library
#     3. find and read documentation for the standard library interactively and online

# %%
# Def: A library is a collection of files or modules that contains functions for use by other programs. 

#Python library has an extensive suite of modules that come with Python

# %%
#Before using a library one needs to import it to load it into the programs memory

import math

# %%
#when we want to use a function from math 
# . means part of
print(math.pi)
# Out:
# 3.141592653589793

# %%
#Use help to learn about the contents of a library module
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/math
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
# ...

# %%
from math import cos, pi # import specific items from a library to shorten programs

# %%
import math as m # create an alias for a library when importing it to shorten programs

# %%
print(m.pi)
# Out:
# 3.141592653589793

# %%
print(round(m.pi, 3)) # an example of nested functions inside function(round) 
                      # evaluated first the outside function (print)
# Out:
# 3.142
